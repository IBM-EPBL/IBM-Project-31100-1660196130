# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255,shear_range=0.2,zoom_range=0.2,horizontal_flip=True)

# %%
test_datagen= ImageDataGenerator(rescale=1./255)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
Data_trainpath='/content/drive/MyDrive/DATASET/TRAIN_SET'

# %%
Data_testpath='/content/drive/MyDrive/DATASET/TRAIN_SET'

# %%
x_train = train_datagen.flow_from_directory(Data_trainpath,target_size=(64,64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 2626 images belonging to 5 classes.

# %%
x_test = train_datagen.flow_from_directory(Data_trainpath,target_size=(64,64),batch_size=5,color_mode='rgb',class_mode='sparse')
# Out:
# Found 2626 images belonging to 5 classes.
